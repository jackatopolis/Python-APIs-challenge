# %%
# WeatherPy.ipynb
# Jack Cohen

# Dependencies
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests as req
from citipy import citipy as cp
from api_keys import weather_key
from scipy import stats

# %%
# Establish latitudes and longitudes to test
lats = 180*np.random.random_sample(1500)-90
longs = 360*np.random.random_sample(1500)-180

for i in range(len(longs)):
    lats[i]=round(lats[i],4)
    longs[i]=round(longs[i],4)

# %%
cities = []
city_list = []
j = 0
print("Beginning Data Retrieval")
print("------------------------")
for i in range(len(lats)):
    city_info = cp.nearest_city(lats[i],longs[i])
    url = f'https://api.openweathermap.org/data/2.5/weather?q={city_info.city_name},{city_info.country_code}&appid={weather_key}&units=imperial'
    try: 
        data = req.get(url).json()
        if f'{city_info.city_name}, {city_info.country_code}' not in city_list:
            cities.append({'city':city_info.city_name,
                           'country':city_info.country_code.upper(),
                           'lat':data['coord']['lat'],
                           'lon':data['coord']['lon'],
                           'temp':data['main']['temp'],
                           'temp_min':data['main']['temp_min'],
                           'temp_max':data['main']['temp_max'],
                           'pressure':data['main']['pressure'],
                           'humidity':data['main']['humidity'],
                           'cloudiness':data['clouds']['all'],
                           'wind_speed':data['wind']['speed'],
                           'timestamp':data['dt']
                       })
            city_list.append(f'{city_info.city_name}, {city_info.country_code}')
            j = j+1
            print(f'Processing City {j} | {city_info.city_name}, {city_info.country_code}')
        else: continue
    except Exception as e:
        print(f'City not found. Skipping...')
print("------------------------")
print("Data Retrieval Complete")
print("------------------------")
# Out:
# Beginning Data Retrieval
# ------------------------
# Processing City 1 | rikitea, pf
# Processing City 2 | ushuaia, ar
# Processing City 3 | ponta do sol, pt
# Processing City 4 | never, ru
# Processing City 5 | mar del plata, ar
# Processing City 6 | boguchany, ru
# Processing City 7 | avarua, ck
# City not found. Skipping...
# Processing City 8 | narsaq, gl
# Processing City 9 | flinders, au
# Processing City 10 | castro, cl
# Processing City 11 | new norfolk, au
# Processing City 12 | roald, no
# City not found. Skipping...
# Processing City 13 | busselton, au
# Processing City 14 | sisimiut, gl
# Processing City 15 | san cristobal, ec
# Processing City 16 | nome, us
# Processing City 17 | butaritari, ki
# Processing City 18 | lumeje, ao
# Processing City 19 | tura, ru
# Processing City 20 | nikolskoye, ru
# City not found. Skipping...
# Processing City 21 | mizdah, ly
# Processing City 22 | yantikovo, ru
# Processing City 23 | georgetown, sh
# Processing City 24 | nhulunbuy, au
# ...

# %%
city_df = pd.DataFrame(data = cities)
city_df = city_df.rename(columns={"city": "City", 
                                  "country": "Country",
                                  "lat":"Latitude",
                                  "lon":"Longitude",
                                  "temp":"Temperature (F)",
                                  "temp_min":"Min Temperature (F)",
                                  "temp_max":"Max Temperature (F)",
                                  "humidity":"Humidity (%)",
                                  "cloudiness":"Cloudiness (%)",
                                  "wind_speed":"Wind Speed (mph)",
                                  "timestamp":"Date (UTC)",
                                  "pressure":"Pressure (hPa)"
                                 })
if len(city_df.loc[city_df['Humidity (%)']>100]) >0:
    print("Humidity value above 100%")
city_df.to_csv('city_data.csv', index=False)
date = datetime.utcfromtimestamp(int(city_df.describe().loc['mean','Date (UTC)']))

# %%
city_df.head()
# Out:
#             City Country  Latitude  Longitude  Temperature (F)  \
# 0        rikitea      PF  -23.1203  -134.9692            73.98
# 1        ushuaia      AR  -54.8000   -68.3000            42.46
# 2   ponta do sol      PT   32.6667   -17.1000            74.28
# 3          never      RU   53.9833   124.1667            59.14
# 4  mar del plata      AR  -38.0023   -57.5575            45.77
#
#    Min Temperature (F)  Max Temperature (F)  Pressure (hPa)  Humidity (%)  \
# 0                73.98                73.98            1019            79
# 1                42.46                44.22            1011            87
# 2                73.13                75.70            1018            76
# 3                59.14                59.14            1001           100
# 4                44.62                47.08            1019            63
#
#    Cloudiness (%)  Wind Speed (mph)  Date (UTC)
# 0              91             13.18  1627500010
# ...

# %%
city_df.describe()
# Out:
#          Latitude   Longitude  Temperature (F)  Min Temperature (F)  \
# count  551.000000  551.000000       551.000000           551.000000
# mean    18.285562   14.793003        69.676933            68.962377
# std     33.677956   92.780713        14.782955            14.643247
# min    -54.800000 -179.166700        32.770000            32.770000
# 25%     -9.046550  -67.366650        57.275000            56.830000
# 50%     20.816700   19.011100        72.320000            72.010000
# 75%     47.835500   96.911550        79.960000            79.360000
# max     78.218600  179.316700       105.130000           105.130000
#
#        Max Temperature (F)  Pressure (hPa)  Humidity (%)  Cloudiness (%)  \
# count           551.000000      551.000000    551.000000      551.000000
# mean             70.490998     1012.047187     69.203267       54.070780
# std              15.179057        7.175308     22.260084       40.597005
# ...

# %%
# Plot Temperature (F) vs Latitude
plt.scatter(city_df['Latitude'],city_df['Max Temperature (F)'],marker = 'o',edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.title(f'Max Temperature (F) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.savefig('weather_plots/maxtemp_vs_lat.png')
plt.show()

# This plot shows how max temperature (for current day) changes with latitude for the cities in the dataset

# %%
# Plot Humidity (%) vs Latitude
plt.scatter(city_df['Latitude'],city_df['Humidity (%)'],marker = 'o',edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.title(f'Humidity (%) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.savefig('weather_plots/humidity_vs_lat.png')
plt.show()

# This plot shows how humidity (for current day) changes with latitude for the cities in the dataset

# %%
# Plot Cloudiness (%) vs Latitude
plt.scatter(city_df['Latitude'],city_df['Cloudiness (%)'],marker = 'o',edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.title(f'Cloudiness (%) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.savefig('weather_plots/cloudiness_vs_lat.png')
plt.show()

# This plot shows how cloudiness (for current day) changes with latitude for the cities in the dataset

# %%
# Plot Wind Speed (mph) vs Latitude
plt.scatter(city_df['Latitude'],city_df['Wind Speed (mph)'],marker = 'o',edgecolors='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.title(f'Wind Speed (mph) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.savefig('weather_plots/wind_speed_vs_lat.png')
plt.show()

# This plot shows how wind speed (for current day) changes with latitude for the cities in the dataset

# %%
# Establish Northern Hemisphere and Southern Hemisphere cities and their data
n_hem_df = city_df.loc[city_df['Latitude']>=0]
s_hem_df = city_df.loc[city_df['Latitude']<=0]

# %%
# Max temperature vs Latitude in Northern Hemisphere, Linear Regression
n_lats = n_hem_df['Latitude']
n_temps = n_hem_df['Max Temperature (F)']

slope,intercept,r,p,std_err = stats.linregress(n_lats,n_temps)
fit = slope*n_lats+intercept

plt.scatter(n_lats, n_temps,marker = 'o', edgecolors='black')
plt.plot(n_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.title(f'Northern Hemisphere - Max Temperature (F) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(10,43),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/north_maxtemp_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how max temperature (for current day) changes with northern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: -0.68644

# %%
# Max temperature vs Latitude in Southern Hemisphere, Linear Regression
s_lats = s_hem_df['Latitude']
s_temps = s_hem_df['Max Temperature (F)']

slope,intercept,r,p,std_err = stats.linregress(s_lats,s_temps)
fit = slope*s_lats+intercept

plt.scatter(s_lats, s_temps,marker = 'o', edgecolors='black')
plt.plot(s_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.grid()
plt.title(f'Southern Hemisphere - Max Temperature (F) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(-50,83),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/south_maxtemp_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how max temperature (for current day) changes with southern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: 0.84454

# %%
# Humidity vs Latitude in Northern Hemisphere, Linear Regression
n_lats = n_hem_df['Latitude']
n_hum = n_hem_df['Humidity (%)']

slope,intercept,r,p,std_err = stats.linregress(n_lats,n_hum)
fit = slope*n_lats+intercept

plt.scatter(n_lats,n_hum,marker = 'o', edgecolors='black')
plt.plot(n_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.title(f'Northern Hemisphere - Humidity (%) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(49,10),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/north_humidity_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how humidity (for current day) changes with northern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: 0.11889

# %%
# Humidity vs Latitude in Southern Hemisphere, Linear Regression
s_lats = s_hem_df['Latitude']
s_hum = s_hem_df['Humidity (%)']

slope,intercept,r,p,std_err = stats.linregress(s_lats,s_hum)
fit = slope*s_lats+intercept

plt.scatter(s_lats,s_hum,marker = 'o', edgecolors='black')
plt.plot(s_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.grid()
plt.title(f'Southern Hemisphere - Humidity (%) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(-55,46),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/south_humidity_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how humidity (for current day) changes with southern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: -0.02661

# %%
# Cloudiness vs Latitude in Northern Hemisphere, Linear Regression
n_lats = n_hem_df['Latitude']
n_cloud = n_hem_df['Cloudiness (%)']

slope,intercept,r,p,std_err = stats.linregress(n_lats,n_cloud)
fit = slope*n_lats+intercept

plt.scatter(n_lats,n_cloud,marker = 'o', edgecolors='black')
plt.plot(n_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.title(f'Northern Hemisphere - Cloudiness (%) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(49,25),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/north_cloudiness_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how cloudiness (for current day) changes with northern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: -0.01953

# %%
# Cloudiness vs Latitude in Southern Hemisphere, Linear Regression
s_lats = s_hem_df['Latitude']
s_cloud = s_hem_df['Cloudiness (%)']

slope,intercept,r,p,std_err = stats.linregress(s_lats,s_cloud)
fit = slope*s_lats+intercept

plt.scatter(s_lats,s_cloud,marker = 'o', edgecolors='black')
plt.plot(s_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.grid()
plt.title(f'Southern Hemisphere - Cloudiness (%) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(-50,61),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/south_cloudiness_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how cloudiness (for current day) changes with southern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: 0.18167

# %%
# Wind Speed vs Latitude in Northern Hemisphere, Linear Regression
n_lats = n_hem_df['Latitude']
n_wind = n_hem_df['Wind Speed (mph)']

slope,intercept,r,p,std_err = stats.linregress(n_lats,n_wind)
fit = slope*n_lats+intercept

plt.scatter(n_lats,n_wind,marker = 'o', edgecolors='black')
plt.plot(n_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.title(f'Northern Hemisphere - Wind Speed (mph) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(50,22),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/north_wind_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how wind speed (for current day) changes with northern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: -0.05525

# %%
# Wind Speed vs Latitude in Southern Hemisphere, Linear Regression
s_lats = s_hem_df['Latitude']
s_wind = s_hem_df['Wind Speed (mph)']

slope,intercept,r,p,std_err = stats.linregress(s_lats,s_wind)
fit = slope*s_lats+intercept

plt.scatter(s_lats,s_wind,marker = 'o', edgecolors='black')
plt.plot(s_lats,fit,'-',color='red')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.grid()
plt.title(f'Southern Hemisphere - Wind Speed (mph) vs. Latitude ({date.month}/{date.day}/{date.year})')
plt.annotate(f'y = {round(slope,2)}x + {round(intercept,2)}',(-50,22),xycoords='data',fontsize=12,color='red');
plt.savefig('weather_plots/south_wind_vs_lat.png')
plt.show()
print(f'The r-value is: {round(r,5)}')

# This plot shows how wind speed (for current day) changes with southern hemisphere latitude for the cities in the dataset
# Out:
# The r-value is: -0.12996
